# %%
import pandas as pd

# %%
df = pd.read_excel("mst.xlsx")

# %%
df
# Out:
#       Sri Aurobindo Institute of Technology, Indore      Unnamed: 1  \
# 0      Department of Computer Science & Engineering             NaN
# 1   MST- I Mark Sheet (May-June 2026) Section-CS-4A             NaN
# 2                                            S. No.  Enrollment no.
# 3                                                 1    0873CS231003
# 4                                                 2    0873CS231022
# ..                                              ...             ...
# 57                                               55    0873CS241058
# 58                                               56    0873CS241059
# 59                                               57    0873CS241060
# 60                                               58    0873CS241061
# 61                                               59    0873CS241062
#
#           Unnamed: 2     Unnamed: 3   Unnamed: 4  Unnamed: 5   Unnamed: 6  \
# 0                NaN            NaN          NaN         NaN          NaN
# ...

# %%
df = df.dropna(columns=[[unnamed:8,un])
# Out:
#   Cell In[11], line 1
#     df = df.dropna(columns=[[unnamed:8,unnamed:9,unnamed:10]])
#                                     ^
# SyntaxError: invalid syntax

# %%
df
# Out:
# Empty DataFrame
# Columns: [Sri Aurobindo Institute of Technology, Indore, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10]
# Index: []
