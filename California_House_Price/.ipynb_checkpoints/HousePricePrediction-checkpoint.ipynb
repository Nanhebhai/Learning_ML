# %%
import pandas as pd

# %%
from sklearn.linear_model import Ridge

# %%
df_train = pd.read_csv("train.csv")

# %%
df_train.shape
# Out:
# (18999, 11)

# %%
df_train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18999 entries, 0 to 18998
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           18999 non-null  float64
#  1   latitude            18999 non-null  float64
#  2   housing_median_age  18999 non-null  int64
#  3   total_rooms         18999 non-null  int64
#  4   total_bedrooms      18807 non-null  float64
#  5   population          18999 non-null  int64
#  6   households          18999 non-null  int64
#  7   median_income       18999 non-null  float64
#  8   median_house_value  18999 non-null  int64
#  9   ocean_proximity     18999 non-null  str
#  10  Unnamed: 10         0 non-null      float64
# dtypes: float64(5), int64(5), str(1)
# memory usage: 1.7 MB

# %%
df_train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  18999.000000  18999.000000        18999.000000  18999.000000
# mean    -119.574147     35.634607           28.685457   2627.143481
# std        2.002828      2.135087           12.582843   2160.289772
# min     -124.350000     32.540000            1.000000      6.000000
# 25%     -121.800000     33.930000           18.000000   1446.000000
# 50%     -118.500000     34.260000           29.000000   2125.000000
# 75%     -118.010000     37.720000           37.000000   3138.500000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    18807.000000  18999.000000  18999.000000   18999.000000
# mean       536.435476   1422.479446    498.693247       3.870569
# std        418.413650   1129.524135    380.546160       1.901732
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df_train.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -117.79     33.71                  16         6339           862.0
# 1    -120.99     39.13                  14          770           116.0
# 2    -118.29     33.88                  21         4946          1231.0
# 3    -117.13     32.72                  52         1560           307.0
# 4    -122.30     38.29                  48         2278           477.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0        3132         825         7.1069              313400       <1H OCEAN
# 1         285         116         3.6434              155400          INLAND
# 2        3186        1167         3.3281              237000       <1H OCEAN
# 3         757         315         2.7083              199100      NEAR OCEAN
# 4        1219         453         2.9643              154000        NEAR BAY
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
df_train.tail(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18994    -122.69     38.27                  32         2344           434.0
# 18995    -122.48     37.78                  52         3047           641.0
# 18996    -118.45     33.96                  24         3097           791.0
# 18997    -118.48     34.16                  30         3507           536.0
# 18998    -118.10     34.10                  34         2578           645.0
#
#        population  households  median_income  median_house_value  \
# 18994        1066         384         4.0313              285000
# 18995        1427         620         3.4883              337200
# 18996        1075         639         5.7230              500001
# 18997        1427         525         6.7082              500001
# 18998        1628         617         2.3400              210900
#
#       ocean_proximity  Unnamed: 10
# 18994       <1H OCEAN          NaN
# 18995        NEAR BAY          NaN
# ...

# %%
df_train.isnull().sum()
# Out:
# longitude                 0
# latitude                  0
# housing_median_age        0
# total_rooms               0
# total_bedrooms          192
# population                0
# households                0
# median_income             0
# median_house_value        0
# ocean_proximity           0
# Unnamed: 10           18999
# dtype: int64

# %%
df_train = df_train.drop("Unnamed: 10",axis=1)

# %%
df_train.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -117.79     33.71                  16         6339           862.0
# 1    -120.99     39.13                  14          770           116.0
# 2    -118.29     33.88                  21         4946          1231.0
# 3    -117.13     32.72                  52         1560           307.0
# 4    -122.30     38.29                  48         2278           477.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0        3132         825         7.1069              313400       <1H OCEAN
# 1         285         116         3.6434              155400          INLAND
# 2        3186        1167         3.3281              237000       <1H OCEAN
# 3         757         315         2.7083              199100      NEAR OCEAN
# 4        1219         453         2.9643              154000        NEAR BAY

# %%
df_train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18999 entries, 0 to 18998
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           18999 non-null  float64
#  1   latitude            18999 non-null  float64
#  2   housing_median_age  18999 non-null  int64
#  3   total_rooms         18999 non-null  int64
#  4   total_bedrooms      18807 non-null  float64
#  5   population          18999 non-null  int64
#  6   households          18999 non-null  int64
#  7   median_income       18999 non-null  float64
#  8   median_house_value  18999 non-null  int64
#  9   ocean_proximity     18999 non-null  str
# dtypes: float64(4), int64(5), str(1)
# memory usage: 1.6 MB

# %%
df_train.shape
# Out:
# (18999, 10)

# %%
x_train =df_train.iloc[:, list(range(8)) + [9]]

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -117.79     33.71                  16         6339           862.0
# 1        -120.99     39.13                  14          770           116.0
# 2        -118.29     33.88                  21         4946          1231.0
# 3        -117.13     32.72                  52         1560           307.0
# 4        -122.30     38.29                  48         2278           477.0
# ...          ...       ...                 ...          ...             ...
# 18994    -122.69     38.27                  32         2344           434.0
# 18995    -122.48     37.78                  52         3047           641.0
# 18996    -118.45     33.96                  24         3097           791.0
# 18997    -118.48     34.16                  30         3507           536.0
# 18998    -118.10     34.10                  34         2578           645.0
#
# ...

# %%
y_train = df_train.iloc[:,[8]]

# %%
y_train
# Out:
#        median_house_value
# 0                  313400
# 1                  155400
# 2                  237000
# 3                  199100
# 4                  154000
# ...                   ...
# 18994              285000
# 18995              337200
# 18996              500001
# 18997              500001
# 18998              210900
#
# [18999 rows x 1 columns]
